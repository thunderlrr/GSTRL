# %%
from torch import nn
import torch

attn = nn.MultiheadAttention(64, 4, batch_first=True)

q = torch.rand(16, 5508, 64)
k = torch.rand(16, 5508, 64)
v = torch.rand(16, 5508, 64)

# %%
attn(q, k, v)
# Out:
# (tensor([[[-0.2238,  0.1420, -0.0816,  ...,  0.0583, -0.1406,  0.4102],
#           [-0.2238,  0.1418, -0.0816,  ...,  0.0583, -0.1406,  0.4102],
#           [-0.2238,  0.1419, -0.0817,  ...,  0.0583, -0.1406,  0.4103],
#           ...,
#           [-0.2237,  0.1419, -0.0816,  ...,  0.0582, -0.1407,  0.4104],
#           [-0.2238,  0.1419, -0.0816,  ...,  0.0582, -0.1407,  0.4103],
#           [-0.2238,  0.1419, -0.0816,  ...,  0.0582, -0.1406,  0.4103]],
#
#          [[-0.2217,  0.1389, -0.0874,  ...,  0.0546, -0.1430,  0.4052],
#           [-0.2217,  0.1389, -0.0873,  ...,  0.0547, -0.1428,  0.4052],
#           [-0.2216,  0.1388, -0.0873,  ...,  0.0547, -0.1429,  0.4052],
#           ...,
#           [-0.2217,  0.1390, -0.0873,  ...,  0.0547, -0.1428,  0.4053],
#           [-0.2217,  0.1388, -0.0873,  ...,  0.0547, -0.1429,  0.4051],
#           [-0.2217,  0.1389, -0.0874,  ...,  0.0547, -0.1429,  0.4051]],
#
# ...
